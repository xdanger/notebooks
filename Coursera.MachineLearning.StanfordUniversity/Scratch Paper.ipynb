# %%
import numpy as np
from sympy import *
x, t, z, nu = symbols('x t z nu')
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# %%
diff(sin(x)*exp(x), x)
# Out:
# exp(x)*sin(x) + exp(x)*cos(x)

# %%
plot(-log(x), (x, 0, 1), xscale='linear')
