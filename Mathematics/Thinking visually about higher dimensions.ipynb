# %%
from mpmath import *
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
import matplotlib as mpl
import mpl_toolkits.axisartist as axisartist
import numpy as np
x, y, z, t = symbols('x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
init_printing()
#import IPython.display
#IPython.display.set_matplotlib_formats('retina')
#%matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
plot(sqrt(x))

# %%
def setup_axes(fig, rect):
    ax = axisartist.Subplot(fig, rect)
    fig.add_axes(ax)
#    ax.axis[:].set_visible(False)
    ax.axis['x'] = ax.new_floating_axis(0, 0)
    ax.axis['x'].set_axisline_style('-|>', size=2.0)
    ax.axis['x'].set_axis_direction('top')
    ax.axis['y'] = ax.new_floating_axis(1, 0)
    ax.axis['y'].set_axisline_style('-|>', size=2.0)
    ax.axis['y'].set_axis_direction('right')
    ax.set_aspect('equal', 'box')
    return ax

fig = plt.figure(figsize=(9, 9))
ax1 = setup_axes(fig, '111')
xx = np.linspace(1, 4, 1000)
ax1.plot(xx, xx**-2, label=r'$\sqrt(N)$')
ax1.set_ylabel(r'$\sqrt\(N)$')
ax1.set_xlim(0, 5)
ax1.set_ylim(0, 1.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# ParseFatalException: Expected \sqrt{value} (at char 5), (line:1, col:6)
#
# During handling of the above exception, another exception occurred:
#
# ParseSyntaxException                      Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2514         try:
# -> 2515             result = self._expression.parseString(s)
#    2516         except ParseBaseException as err:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1631                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1632                 raise exc
#    1633         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1621         try:
# -> 1622             loc, tokens = self._parse( instring, 0 )
#    1623             if parseAll:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3394             else:
# -> 3395                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3396             if exprtokens or exprtokens.haskeys():
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3918         try:
# -> 3919             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    3920         except (ParseException,IndexError):
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3847             try_not_ender(instring, loc)
# -> 3848         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    3849         try:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3377         # pre-parsed the string as part of our And pre-parsing
# -> 3378         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3379         errorStop = False
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1404                 for fn in self.parseAction:
# -> 1405                     tokens = fn( instring, tokensStart, retTokens )
#    1406                     if tokens is not None:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in wrapper(*args)
#    1048             try:
# -> 1049                 ret = func(*args[limit[0]:])
#    1050                 foundArity[0] = True
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/mathtext.py in math_string(self, s, loc, toks)
#    2583     def math_string(self, s, loc, toks):
# -> 2584         return self._math_expression.parseString(toks[0][1:-1])
#    2585
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1631                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1632                 raise exc
#    1633         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1621         try:
# -> 1622             loc, tokens = self._parse( instring, 0 )
#    1623             if parseAll:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3847             try_not_ender(instring, loc)
# -> 3848         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    3849         try:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3377         # pre-parsed the string as part of our And pre-parsing
# -> 3378         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3379         errorStop = False
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3982         try:
# -> 3983             loc, tokens = self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3984         except (ParseException,IndexError):
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1528                 try:
# -> 1529                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1530                 except ParseBaseException as pe:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#
# /anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3390                     pe.__traceback__ = None
# -> 3391                     raise ParseSyntaxException._from_exception(pe)
#    3392                 except IndexError:
#
# ParseSyntaxException: Expected \sqrt{value} (at char 5), (line:1, col:6)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     245         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#     246     if 'svg' in formats:
# --> 247         svg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'svg', **kwargs))
#     248     if 'pdf' in formats:
#     249         pdf_formatter.for_type(Figure, lambda fig: print_figure(fig, 'pdf', **kwargs))
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1208                 detach = True
#    1209
# -> 1210             result = self._print_svg(filename, fh, **kwargs)
#    1211
#    1212             # Detach underlying stream from wrapper so that it remains open in
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_svg.py in _print_svg(self, filename, fh, **kwargs)
#    1238             bbox_inches_restore=_bbox_inches_restore)
#    1239
# -> 1240         self.figure.draw(renderer)
#    1241         renderer.finalize()
#    1242
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/axisartist/axislines.py in draw(self, renderer, inframe)
#     754         self.artists = self.artists + list(self._axislines.values()) + [self.gridlines]
#     755
# --> 756         super(Axes, self).draw(renderer, inframe)
#     757
#     758         self.artists = orig_artists
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/axisartist/axis_artist.py in draw(self, renderer)
#    1482
#    1483         #self._draw_offsetText(renderer)
# -> 1484         self._draw_label(renderer)
#    1485
#    1486         renderer.close_group(__name__)
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/axisartist/axis_artist.py in _draw_label(self, renderer)
#    1375     def _draw_label(self, renderer):
#    1376         self._update_label(renderer)
# -> 1377         self.label.draw(renderer)
#    1378
#    1379     def _draw_label2(self, renderer):
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/axisartist/axis_artist.py in draw(self, renderer)
#     575         self._set_offset_radius(r)
#     576
# --> 577         super(AxisLabel, self).draw(renderer)
#     578
#     579
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/axisartist/axis_artist.py in draw(self, renderer)
#     408         offset_tr.translate(dx, dy)
#     409         self.set_rotation(text_ref_angle+angle_orig)
# --> 410         super(LabelBase, self).draw(renderer)
#     411         offset_tr.clear()
#     412
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     704
#     705         with _wrap_text(self) as textobj:
# --> 706             bbox, info, descent = textobj._get_layout(renderer)
#     707             trans = textobj.get_transform()
#     708
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     307                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     308                                                         self._fontproperties,
# --> 309                                                         ismath=ismath)
#     310             else:
#     311                 w, h, d = 0, 0, 0
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_svg.py in get_text_width_height_descent(self, s, prop, ismath)
#    1183
#    1184     def get_text_width_height_descent(self, s, prop, ismath):
# -> 1185         return self._text2path.get_text_width_height_descent(s, prop, ismath)
#    1186
#    1187
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/textpath.py in get_text_width_height_descent(self, s, prop, ismath)
#     110
#     111             width, height, descent, trash, used_characters = \
# --> 112                 self.mathtext_parser.parse(s, 72, prop)
#     113             return width * scale, height * scale, descent * scale
#     114
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3291             self.__class__._parser = Parser()
#    3292
# -> 3293         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3294         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3295         result = font_output.get_results(box)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2519                         err.line,
#    2520                         " " * (err.column - 1) + "^",
# -> 2521                         six.text_type(err)]))
#    2522         self._state_stack = None
#    2523         self._em_width_cache = {}
#
# ValueError:
# \sqrt(N)
#      ^
# Expected \sqrt{value} (at char 5), (line:1, col:6)
