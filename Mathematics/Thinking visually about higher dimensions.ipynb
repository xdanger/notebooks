# %%
from mpmath import *
from sympy import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
import matplotlib as mpl
import mpl_toolkits.axisartist as axisartist
import numpy as np
x, y, z, t = symbols('x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
init_printing()
#import IPython.display
#IPython.display.set_matplotlib_formats('retina')
#%matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
xx = np.linspace(1, 10, 100)
yy = np.sqrt(xx)
xi = np.arange(11)[1:11]
yi = np.sqrt(xi)
fig, ax = plt.subplots(1, 1)
ax.plot(xx, yy, 'b--', linewidth=1.0, label=r'$\sqrt(N)$')
ax.plot(xi, yi, 'bo', markersize=4.0)
ax.plot(xx, np.linspace(1, 1, 100), 'g--', linewidth=1.0)
#ax.set_aspect('equal', 'box')
plt.show()

# %%
plot(sqrt(1/x), (x, 0, 9), ylim=[0, 1.2])

# %%
xx = np.linspace(2, 100, 100)
fig, ax = plt.subplots(1, 1)
ax.plot(xx, (np.sqrt(xx*1**2) - 1), 'go', linewidth=1.0, markersize=1.0)
ax.plot(xx, (np.sqrt(xx*1**2) - 1)**(1/xx), 'bo', linewidth=1.0, markersize=1.0)
ax.set_xlabel(r'$N$ dimensions')
ax.set_ylabel(r'The most')
plt.show()

# %% [markdown]
# 随着维度 $N$ 的升高，中心切“球”与坐标轴
